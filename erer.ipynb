-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [benjaminGarridoDatabase]
GO

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 04/11/2022 15:52:47 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Claims]

-- %%
/****** Object:  Table [dbo].[Claims]    Script Date: 04/11/2022 15:52:47 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Claims](
	[ClaimId] [numeric](18, 0) NOT NULL,
	[Description] [varchar](50) NULL,
	[Status] [varchar](50) NULL,
	[date] [date] NULL,
	[Vehicle_Id] [numeric](18, 0) NULL,
 CONSTRAINT [PK_Claims] PRIMARY KEY CLUSTERED 
(
	[ClaimId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Owner]

-- %%
/****** Object:  Table [dbo].[Owner]    Script Date: 04/11/2022 15:52:47 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Owner](
	[OwnerId] [numeric](18, 0) NOT NULL,
	[FirstName] [ntext] NULL,
	[LastNme] [ntext] NULL,
	[DriverLicense] [bit] NULL,
 CONSTRAINT [PK_Owner] PRIMARY KEY CLUSTERED 
(
	[OwnerId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Vehicles]

-- %%
/****** Object:  Table [dbo].[Vehicles]    Script Date: 04/11/2022 15:52:47 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Vehicles](
	[VehiclesId] [numeric](18, 0) NOT NULL,
	[Brand] [varchar](50) NULL,
	[Vin] [varchar](50) NULL,
	[Color] [varchar](50) NULL,
	[year] [varchar](50) NULL,
	[Owner_Id] [numeric](18, 0) NULL,
 CONSTRAINT [PK_Vehicles] PRIMARY KEY CLUSTERED 
(
	[VehiclesId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [Vehicle_Id]

-- %%
ALTER TABLE [dbo].[Claims]  WITH CHECK ADD  CONSTRAINT [Vehicle_Id] FOREIGN KEY([Vehicle_Id])
REFERENCES [dbo].[Vehicles] ([VehiclesId])
GO
ALTER TABLE [dbo].[Claims] CHECK CONSTRAINT [Vehicle_Id]
GO

-- %% [markdown]
-- # [Owner_Id]

-- %%
ALTER TABLE [dbo].[Vehicles]  WITH CHECK ADD  CONSTRAINT [Owner_Id] FOREIGN KEY([Owner_Id])
REFERENCES [dbo].[Vehicles] ([VehiclesId])
GO
ALTER TABLE [dbo].[Vehicles] CHECK CONSTRAINT [Owner_Id]
GO
